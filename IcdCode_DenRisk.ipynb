# %% [markdown]
# ##  MODULE 1 — CLINICAL NOTE AUTO-CODING (NLP)

# %% [markdown]
# # Importing Relevant Libraries

# %%
from openai import OpenAI
import pandas as pd
import re

client = OpenAI(api_key="sk-proj-wjYSA0JvApzRnMBewl4f8QTT5GJaSP90PHgfB9_b14UXEq9UvCd-ZLAblBDmDNMA")

# %% [markdown]
# # Cleaning The Data

# %%
def clean(t):
    t = re.sub(r"\[\*\*.*?\*\*\]", " ", t)
    return re.sub(r"\s+", " ", t).strip()

# %% [markdown]
# # Example Usage

# %%
FEW_SHOT = """
You are a medical coding expert. Your task is to predict ICD-9 or ICD-10 codes
based on a clinical discharge summary or symptoms.

Return ONLY the ICD codes as a Python list.

Example 1:
Summary:
"Patient admitted with chest pain radiating to left arm, troponin elevated,
diagnosed with acute myocardial infarction."
ICD codes: ["I21.3"]

Example 2:
Summary:
"75-year-old female with fever, cough, and right lower lobe pneumonia."
ICD codes: ["J18.9"]

Example 3:
Summary:
"Patient with uncontrolled type 2 diabetes and diabetic neuropathy."
ICD codes: ["E11.40"]

Now predict ICD codes for the following summary.
Summary: 
"""

# %% [markdown]
# # ICD Code Predictor

# %%
def predict_icd(summary):
    summary = clean(summary)
    query = FEW_SHOT + summary + "\nICD codes:"

    response = client.responses.create(
        model="gpt-4o-mini",
        input=query
    )

    output = response.output_text

    # Extract ICD codes using regex
    codes = re.findall(r"[A-TV-Z]\d{1,3}\.?\d*|\d{3}\.?\d*", output)
    return codes

# %% [markdown]
# # Creating User Prompt

# %%
while True:
    print("\n--------------------------------------------")
    summary = input("Enter symptoms / discharge summary (or type 'exit'): ")

    if summary.lower().strip() == "exit":
        print("Exiting ICD predictor...")   # ← prevents Jupyter cell from disappearing
        break

    icd_codes = predict_icd(summary)
    print("\nPredicted ICD Codes:", icd_codes)
# Out:
# --------------------------------------------
# Enter symptoms / discharge summary (or type 'exit'):  patient was having headache, cold and fever
# Predicted ICD Codes: ['R51', 'J20.9', 'R50.9']
#
# --------------------------------------------
# Enter symptoms / discharge summary (or type 'exit'):  another patient was having bloating, chest pain
# Predicted ICD Codes: ['R14.0', 'R07.9']
#
# --------------------------------------------
# Enter symptoms / discharge summary (or type 'exit'):  exit
# Exiting ICD predictor...

# %% [markdown]
# # MODULE 2 — CLAIM DENIAL RISK PREDICTION

# %% [markdown]
# # Importing Relevant Libraries

# %%
import os
import numpy as np
import pandas as pd
from xgboost.callback import EarlyStopping
from datetime import datetime
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, precision_recall_fscore_support
from scipy.sparse import hstack
from sklearn.feature_extraction.text import CountVectorizer
import joblib
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Copying the Data

# %%
patients = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\PATIENTS.csv\PATIENTS.csv")
admissions = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\ADMISSIONS.csv\ADMISSIONS.csv")
diag_icd = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\DIAGNOSES_ICD.csv\DIAGNOSES_ICD.csv")
proc_icd = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\PROCEDURES_ICD.csv\PROCEDURES_ICD.csv")
dicd_diag = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\D_ICD_DIAGNOSES.csv\D_ICD_DIAGNOSES.csv")
dicd_proc = pd.read_csv(r"C:\Users\ashee\OneDrive\Desktop\Ntigra Job Application\archive\mimic-iii-clinical-database-1.4\D_ICD_PROCEDURES.csv\D_ICD_PROCEDURES.csv")

# %% [markdown]
# # Removing Unnecessary Columns

# %%
patients = patients[['SUBJECT_ID', 'GENDER']]
patients.head()
# Out:
#    SUBJECT_ID GENDER
# 0         249      F
# 1         250      F
# 2         251      M
# 3         252      M
# 4         253      F

# %% [markdown]
# # Checking Null Values

# %%
patients.isnull().sum()
# Out:
# SUBJECT_ID    0
# GENDER        0
# dtype: int64

# %% [markdown]
# # Removing Unnecessary Columns

# %%
admissions = admissions[['SUBJECT_ID', 'HADM_ID', 'ADMITTIME', 'DISCHTIME','ADMISSION_TYPE', 'ADMISSION_LOCATION',
                         'DISCHARGE_LOCATION', 'INSURANCE','DIAGNOSIS']]
admissions.head()
# Out:
#    SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   ADMISSION_TYPE         ADMISSION_LOCATION         DISCHARGE_LOCATION  \
# 0      EMERGENCY       EMERGENCY ROOM ADMIT  DISC-TRAN CANCER/CHLDRN H
# 1       ELECTIVE  PHYS REFERRAL/NORMAL DELI           HOME HEALTH CARE
# 2      EMERGENCY  TRANSFER FROM HOSP/EXTRAM           HOME HEALTH CARE
# 3      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                       HOME
# 4      EMERGENCY       EMERGENCY ROOM ADMIT                       HOME
#
#   INSURANCE                                          DIAGNOSIS
# 0   Private                            BENZODIAZEPINE OVERDOSE
# 1  Medicare  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 2  Medicare                                         BRAIN MASS
# 3   Private                     INTERIOR MYOCARDIAL INFARCTION
# 4   Private                            ACUTE CORONARY SYNDROME

# %% [markdown]
# # Checking Null Values and Removing Them

# %%
admissions.isnull().sum()
# Out:
# SUBJECT_ID             0
# HADM_ID                0
# ADMITTIME              0
# DISCHTIME              0
# ADMISSION_TYPE         0
# ADMISSION_LOCATION     0
# DISCHARGE_LOCATION     0
# INSURANCE              0
# DIAGNOSIS             25
# dtype: int64

# %%
admissions = admissions.dropna()

# %%
admissions.isnull().sum()
# Out:
# SUBJECT_ID            0
# HADM_ID               0
# ADMITTIME             0
# DISCHTIME             0
# ADMISSION_TYPE        0
# ADMISSION_LOCATION    0
# DISCHARGE_LOCATION    0
# INSURANCE             0
# DIAGNOSIS             0
# dtype: int64

# %%
len(admissions)
# Out:
# 58951

# %%
diag_icd = diag_icd[['SUBJECT_ID', 'HADM_ID','ICD9_CODE']]
diag_icd.head()
# Out:
#    SUBJECT_ID  HADM_ID ICD9_CODE
# 0         109   172335     40301
# 1         109   172335       486
# 2         109   172335     58281
# 3         109   172335      5855
# 4         109   172335      4254

# %%
diag_icd.isnull().sum()
# Out:
# SUBJECT_ID     0
# HADM_ID        0
# ICD9_CODE     47
# dtype: int64

# %%
diag_icd = diag_icd.dropna()
diag_icd.isnull().sum()
# Out:
# SUBJECT_ID    0
# HADM_ID       0
# ICD9_CODE     0
# dtype: int64

# %% [markdown]
# # Removing Unnecessary Columns

# %%
proc_icd = proc_icd[['SUBJECT_ID', 'HADM_ID','ICD9_CODE']]
proc_icd.head()
# Out:
#    SUBJECT_ID  HADM_ID  ICD9_CODE
# 0       62641   154460       3404
# 1        2592   130856       9671
# 2        2592   130856       3893
# 3       55357   119355       9672
# 4       55357   119355        331

# %%
dicd_diag = dicd_diag[['ICD9_CODE', 'SHORT_TITLE']]
dicd_diag.head()
# Out:
#   ICD9_CODE               SHORT_TITLE
# 0     01166     TB pneumonia-oth test
# 1     01170    TB pneumothorax-unspec
# 2     01171   TB pneumothorax-no exam
# 3     01172  TB pneumothorx-exam unkn
# 4     01173  TB pneumothorax-micro dx

# %% [markdown]
# # Checking Null Values

# %%
dicd_diag.isnull().sum()
# Out:
# ICD9_CODE      0
# SHORT_TITLE    0
# dtype: int64

# %%
dicd_proc = dicd_proc[['ICD9_CODE', 'SHORT_TITLE']]
dicd_proc.head()
# Out:
#    ICD9_CODE               SHORT_TITLE
# 0        851                Canthotomy
# 1        852           Blepharorrhaphy
# 2        859   Adjust lid position NEC
# 3        861  Lid reconst w skin graft
# 4        862   Lid reconst w muc graft

# %%
dicd_proc.isnull().sum()
# Out:
# ICD9_CODE      0
# SHORT_TITLE    0
# dtype: int64

# %% [markdown]
#  # THERE IS NO TARGET COLUMN IN THE DATASET. THAT IS WHY WE HAVE TO CREATE A SYNTHETIC COLUMN BUT BECAUSE IT IS NOT A REAL DATA THAT IS WHY THIS ENTIRE CODE IS JUST A BLUE PRINT"

# %%
target_col = None
for c in ["DENIED", "CLAIM_DENIED", "CLAIM_STATUS", "DENIAL", "IS_DENIED"]:
    if c in admissions.columns:
        target_col = c
        break

if target_col is None:
    print("\nNo denial label found in ADMISSIONS. Creating a synthetic demo target 'DENIED' (random).")
    np.random.seed(42)
    admissions['DENIED'] = np.random.binomial(1, 0.15, size=len(admissions))  # 15% synthetic denial rate
    target_col = 'DENIED'
else:
    print(f"\nFound target column in ADMISSIONS: {target_col}. Using that as label.")
# Out:
# No denial label found in ADMISSIONS. Creating a synthetic demo target 'DENIED' (random).

# %%
admissions.head()
# Out:
#    SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   ADMISSION_TYPE         ADMISSION_LOCATION         DISCHARGE_LOCATION  \
# 0      EMERGENCY       EMERGENCY ROOM ADMIT  DISC-TRAN CANCER/CHLDRN H
# 1       ELECTIVE  PHYS REFERRAL/NORMAL DELI           HOME HEALTH CARE
# 2      EMERGENCY  TRANSFER FROM HOSP/EXTRAM           HOME HEALTH CARE
# 3      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                       HOME
# 4      EMERGENCY       EMERGENCY ROOM ADMIT                       HOME
#
#   INSURANCE                                          DIAGNOSIS  DENIED
# 0   Private                            BENZODIAZEPINE OVERDOSE       0
# 1  Medicare  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...       1
# 2  Medicare                                         BRAIN MASS       0
# 3   Private                     INTERIOR MYOCARDIAL INFARCTION       0
# 4   Private                            ACUTE CORONARY SYNDROME       0

# %% [markdown]
# # Preparing patient-level features: admission, gender

# %%
print("\nBuilding core features...")
# merge patients -> admissions
ad = admissions.merge(patients[['SUBJECT_ID', 'GENDER']], on='SUBJECT_ID', how='left')

# select core categorical features from admissions
core_cat = ['ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'INSURANCE', 'MARITAL_STATUS', 'ETHNICITY']
for c in core_cat:
    if c not in ad.columns:
        ad[c] = np.nan
# Out:
# Building core features...

# %% [markdown]
# # Building diagnosis and procedure aggregated features (per admission)

# %%
# Create aggregated string of ICD codes per HADM_ID for diagnoses and procedures
print("Aggregating ICD codes per admission...")
diag_per_adm = diag_icd.groupby('HADM_ID')['ICD9_CODE'].agg(lambda codes: ' '.join(map(str, codes.dropna().astype(str)))).reset_index().rename(columns={'ICD9_CODE':'DIAG_CODES'})
proc_per_adm = proc_icd.groupby('HADM_ID')['ICD9_CODE'].agg(lambda codes: ' '.join(map(str, codes.dropna().astype(str)))).reset_index().rename(columns={'ICD9_CODE':'PROC_CODES'})

# merge into admissions dataframe (ad)
ad = ad.merge(diag_per_adm, on='HADM_ID', how='left')
ad = ad.merge(proc_per_adm, on='HADM_ID', how='left')

# Replace NaN strings with empty
ad['DIAG_CODES'] = ad['DIAG_CODES'].fillna("")
ad['PROC_CODES'] = ad['PROC_CODES'].fillna("")
# Out:
# Aggregating ICD codes per admission...

# %% [markdown]
# # Feature engineering from ICD text: top-N code bag-of-codes (CountVectorizer on codes)

# %%
# Use CountVectorizer tokenizing on whitespace because ICD codes are space-separated strings
top_n_diag = 500   # adjustable
top_n_proc = 300   # adjustable

print(f"Vectorizing top {top_n_diag} diagnosis codes and top {top_n_proc} procedure codes...")
diag_vec = CountVectorizer(token_pattern=r"[^ ]+", max_features=top_n_diag, binary=True)
proc_vec = CountVectorizer(token_pattern=r"[^ ]+", max_features=top_n_proc, binary=True)

diag_X = diag_vec.fit_transform(ad['DIAG_CODES'])
proc_X = proc_vec.fit_transform(ad['PROC_CODES'])

# small numeric features
num_df = ad[['HADM_ID']].set_index('HADM_ID')

# categorical features: we will one-hot encode a selected small set
cat_cols = ['GENDER', 'ADMISSION_TYPE', 'INSURANCE', 'MARITAL_STATUS', 'ETHNICITY']
ad_cats = ad[cat_cols].fillna('MISSING')
ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)
cat_X = ohe.fit_transform(ad_cats)
# Out:
# Vectorizing top 500 diagnosis codes and top 300 procedure codes...

# %% [markdown]
# # Combining all features into X (sparse)

# %%
print("Combining numeric, categorical, and ICD features...")
from scipy.sparse import csr_matrix
num_X = csr_matrix(num_df.values)  # convert numeric to sparse
X = hstack([num_X, cat_X, diag_X, proc_X], format='csr')

# Align y (target) to HADM_ID order
y = ad.set_index('HADM_ID')[target_col].reindex(index=num_df.index).values
print("Feature matrix shape:", X.shape)
print("Target distribution:", pd.Series(y).value_counts())
# Out:
# Combining numeric, categorical, and ICD features...
# Feature matrix shape: (58951, 813)
# Target distribution: 0    50142
# 1     8809
# Name: count, dtype: int64

# %% [markdown]
# # Train / Test split (stratified)

# %%
print("\nSplitting data...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
# Out:
# Splitting data...

# %% [markdown]
# # Model training - XGBoost (with early stopping) and RandomForest for comparison

# %%
print("\nTraining XGBoost...")
xgb = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric='auc',
    random_state=42,
    n_jobs=-1
)

# Fit with early stopping: need validation set from train
X_tr_sub, X_val_sub, y_tr_sub, y_val_sub = train_test_split(X_train, y_train, test_size=0.15, stratify=y_train, random_state=42)
xgb.fit(X_tr_sub, y_tr_sub, eval_set=[(X_val_sub, y_val_sub)],verbose=True)
# Out:
# Training XGBoost...
# [0]	validation_0-auc:0.49916
# [1]	validation_0-auc:0.49974
# [2]	validation_0-auc:0.50066
# [3]	validation_0-auc:0.50130
# [4]	validation_0-auc:0.50229
# [5]	validation_0-auc:0.50141
# [6]	validation_0-auc:0.50171
# [7]	validation_0-auc:0.50255
# [8]	validation_0-auc:0.49988
# [9]	validation_0-auc:0.50019
# [10]	validation_0-auc:0.49761
# [11]	validation_0-auc:0.49649
# [12]	validation_0-auc:0.49967
# [13]	validation_0-auc:0.49925
# [14]	validation_0-auc:0.49916
# [15]	validation_0-auc:0.49962
# [16]	validation_0-auc:0.49925
# [17]	validation_0-auc:0.49937
# [18]	validation_0-auc:0.49895
# [19]	validation_0-auc:0.49889
# [20]	validation_0-auc:0.50033
# [21]	validation_0-auc:0.50069
# [22]	validation_0-auc:0.50028
# [23]	validation_0-auc:0.50132
# [24]	validation_0-auc:0.50332
# [25]	validation_0-auc:0.50489
# [26]	validation_0-auc:0.50427
# [27]	validation_0-auc:0.50808
# [28]	validation_0-auc:0.50950
# [29]	validation_0-auc:0.50904
# [30]	validation_0-auc:0.50849
# [31]	validation_0-auc:0.50966
# [32]	validation_0-auc:0.50908
# [33]	validation_0-auc:0.50851
# [34]	validation_0-auc:0.50909
# [35]	validation_0-auc:0.50955
# [36]	validation_0-auc:0.50718
# [37]	validation_0-auc:0.50540
# [38]	validation_0-auc:0.50381
# [39]	validation_0-auc:0.50524
# [40]	validation_0-auc:0.50771
# [41]	validation_0-auc:0.50795
# [42]	validation_0-auc:0.50868
# [43]	validation_0-auc:0.50717
# [44]	validation_0-auc:0.50780
# [45]	validation_0-auc:0.50634
# [46]	validation_0-auc:0.50682
# [47]	validation_0-auc:0.50785
# [48]	validation_0-auc:0.50785
# [49]	validation_0-auc:0.50855
# [50]	validation_0-auc:0.50813
# [51]	validation_0-auc:0.50661
# [52]	validation_0-auc:0.50580
# [53]	validation_0-auc:0.50568
# [54]	validation_0-auc:0.50738
# [55]	validation_0-auc:0.50847
# [56]	validation_0-auc:0.50933
# [57]	validation_0-auc:0.50839
# [58]	validation_0-auc:0.50913
# [59]	validation_0-auc:0.50888
# [60]	validation_0-auc:0.50930
# [61]	validation_0-auc:0.50797
# [62]	validation_0-auc:0.50640
# [63]	validation_0-auc:0.50630
# [64]	validation_0-auc:0.50624
# [65]	validation_0-auc:0.50550
# [66]	validation_0-auc:0.50440
# [67]	validation_0-auc:0.50522
# [68]	validation_0-auc:0.50422
# [69]	validation_0-auc:0.50305
# [70]	validation_0-auc:0.50500
# [71]	validation_0-auc:0.50592
# [72]	validation_0-auc:0.50639
# [73]	validation_0-auc:0.50576
# [74]	validation_0-auc:0.50790
# [75]	validation_0-auc:0.50876
# [76]	validation_0-auc:0.50922
# [77]	validation_0-auc:0.50764
# [78]	validation_0-auc:0.50706
# [79]	validation_0-auc:0.50548
# [80]	validation_0-auc:0.50633
# [81]	validation_0-auc:0.50663
# [82]	validation_0-auc:0.50659
# [83]	validation_0-auc:0.50557
# [84]	validation_0-auc:0.50515
# [85]	validation_0-auc:0.50449
# [86]	validation_0-auc:0.50421
# [87]	validation_0-auc:0.50464
# [88]	validation_0-auc:0.50381
# [89]	validation_0-auc:0.50404
# [90]	validation_0-auc:0.50468
# [91]	validation_0-auc:0.50440
# [92]	validation_0-auc:0.50401
# [93]	validation_0-auc:0.50371
# [94]	validation_0-auc:0.50347
# [95]	validation_0-auc:0.50446
# [96]	validation_0-auc:0.50504
# [97]	validation_0-auc:0.50464
# [98]	validation_0-auc:0.50548
# [99]	validation_0-auc:0.50607
# [100]	validation_0-auc:0.50511
# [101]	validation_0-auc:0.50634
# [102]	validation_0-auc:0.50622
# [103]	validation_0-auc:0.50570
# [104]	validation_0-auc:0.50591
# [105]	validation_0-auc:0.50633
# [106]	validation_0-auc:0.50524
# [107]	validation_0-auc:0.50668
# [108]	validation_0-auc:0.50724
# [109]	validation_0-auc:0.50715
# [110]	validation_0-auc:0.50709
# [111]	validation_0-auc:0.50730
# [112]	validation_0-auc:0.50630
# [113]	validation_0-auc:0.50642
# [114]	validation_0-auc:0.50678
# [115]	validation_0-auc:0.50661
# [116]	validation_0-auc:0.50731
# [117]	validation_0-auc:0.50786
# [118]	validation_0-auc:0.50882
# [119]	validation_0-auc:0.50709
# [120]	validation_0-auc:0.50774
# [121]	validation_0-auc:0.50685
# [122]	validation_0-auc:0.50701
# [123]	validation_0-auc:0.50622
# [124]	validation_0-auc:0.50629
# [125]	validation_0-auc:0.50554
# [126]	validation_0-auc:0.50571
# [127]	validation_0-auc:0.50657
# [128]	validation_0-auc:0.50678
# [129]	validation_0-auc:0.50849
# [130]	validation_0-auc:0.50816
# [131]	validation_0-auc:0.50750
# [132]	validation_0-auc:0.50789
# [133]	validation_0-auc:0.50757
# [134]	validation_0-auc:0.50732
# [135]	validation_0-auc:0.50841
# [136]	validation_0-auc:0.51002
# [137]	validation_0-auc:0.51072
# [138]	validation_0-auc:0.50942
# [139]	validation_0-auc:0.50923
# [140]	validation_0-auc:0.50962
# [141]	validation_0-auc:0.50846
# [142]	validation_0-auc:0.50850
# [143]	validation_0-auc:0.50864
# [144]	validation_0-auc:0.50864
# [145]	validation_0-auc:0.50875
# [146]	validation_0-auc:0.50848
# [147]	validation_0-auc:0.50886
# [148]	validation_0-auc:0.50816
# [149]	validation_0-auc:0.50808
# [150]	validation_0-auc:0.50850
# [151]	validation_0-auc:0.50845
# [152]	validation_0-auc:0.50847
# [153]	validation_0-auc:0.50841
# [154]	validation_0-auc:0.50912
# [155]	validation_0-auc:0.50890
# [156]	validation_0-auc:0.50924
# [157]	validation_0-auc:0.50966
# [158]	validation_0-auc:0.50972
# [159]	validation_0-auc:0.51012
# [160]	validation_0-auc:0.50910
# [161]	validation_0-auc:0.50886
# [162]	validation_0-auc:0.50798
# [163]	validation_0-auc:0.50828
# [164]	validation_0-auc:0.50843
# [165]	validation_0-auc:0.50873
# [166]	validation_0-auc:0.50894
# [167]	validation_0-auc:0.50910
# [168]	validation_0-auc:0.50905
# [169]	validation_0-auc:0.50896
# [170]	validation_0-auc:0.50937
# [171]	validation_0-auc:0.50902
# [172]	validation_0-auc:0.50854
# [173]	validation_0-auc:0.50817
# [174]	validation_0-auc:0.50805
# [175]	validation_0-auc:0.50813
# [176]	validation_0-auc:0.50820
# [177]	validation_0-auc:0.50844
# [178]	validation_0-auc:0.50722
# [179]	validation_0-auc:0.50699
# [180]	validation_0-auc:0.50671
# [181]	validation_0-auc:0.50725
# [182]	validation_0-auc:0.50658
# [183]	validation_0-auc:0.50662
# [184]	validation_0-auc:0.50817
# [185]	validation_0-auc:0.50712
# [186]	validation_0-auc:0.50791
# [187]	validation_0-auc:0.50866
# [188]	validation_0-auc:0.50805
# [189]	validation_0-auc:0.50827
# [190]	validation_0-auc:0.50875
# [191]	validation_0-auc:0.50925
# [192]	validation_0-auc:0.50958
# [193]	validation_0-auc:0.50993
# [194]	validation_0-auc:0.51030
# [195]	validation_0-auc:0.50986
# [196]	validation_0-auc:0.50910
# [197]	validation_0-auc:0.50924
# [198]	validation_0-auc:0.50890
# [199]	validation_0-auc:0.50908
# [200]	validation_0-auc:0.50935
# [201]	validation_0-auc:0.50851
# [202]	validation_0-auc:0.50914
# [203]	validation_0-auc:0.51015
# [204]	validation_0-auc:0.50853
# [205]	validation_0-auc:0.50848
# [206]	validation_0-auc:0.50774
# [207]	validation_0-auc:0.50746
# [208]	validation_0-auc:0.50778
# [209]	validation_0-auc:0.50812
# [210]	validation_0-auc:0.50790
# [211]	validation_0-auc:0.50753
# [212]	validation_0-auc:0.50665
# [213]	validation_0-auc:0.50714
# [214]	validation_0-auc:0.50674
# [215]	validation_0-auc:0.50614
# [216]	validation_0-auc:0.50630
# [217]	validation_0-auc:0.50642
# [218]	validation_0-auc:0.50623
# [219]	validation_0-auc:0.50593
# [220]	validation_0-auc:0.50604
# [221]	validation_0-auc:0.50629
# [222]	validation_0-auc:0.50605
# [223]	validation_0-auc:0.50596
# [224]	validation_0-auc:0.50613
# [225]	validation_0-auc:0.50606
# [226]	validation_0-auc:0.50562
# [227]	validation_0-auc:0.50576
# [228]	validation_0-auc:0.50562
# [229]	validation_0-auc:0.50527
# [230]	validation_0-auc:0.50480
# [231]	validation_0-auc:0.50499
# [232]	validation_0-auc:0.50507
# [233]	validation_0-auc:0.50569
# [234]	validation_0-auc:0.50606
# [235]	validation_0-auc:0.50622
# [236]	validation_0-auc:0.50669
# [237]	validation_0-auc:0.50682
# [238]	validation_0-auc:0.50641
# [239]	validation_0-auc:0.50640
# [240]	validation_0-auc:0.50632
# [241]	validation_0-auc:0.50640
# [242]	validation_0-auc:0.50666
# [243]	validation_0-auc:0.50633
# [244]	validation_0-auc:0.50593
# [245]	validation_0-auc:0.50618
# [246]	validation_0-auc:0.50628
# [247]	validation_0-auc:0.50544
# [248]	validation_0-auc:0.50517
# [249]	validation_0-auc:0.50543
# [250]	validation_0-auc:0.50531
# [251]	validation_0-auc:0.50525
# [252]	validation_0-auc:0.50576
# [253]	validation_0-auc:0.50644
# [254]	validation_0-auc:0.50631
# [255]	validation_0-auc:0.50617
# [256]	validation_0-auc:0.50611
# [257]	validation_0-auc:0.50591
# [258]	validation_0-auc:0.50544
# [259]	validation_0-auc:0.50529
# [260]	validation_0-auc:0.50571
# [261]	validation_0-auc:0.50577
# [262]	validation_0-auc:0.50636
# [263]	validation_0-auc:0.50623
# [264]	validation_0-auc:0.50627
# [265]	validation_0-auc:0.50633
# [266]	validation_0-auc:0.50635
# [267]	validation_0-auc:0.50654
# [268]	validation_0-auc:0.50614
# [269]	validation_0-auc:0.50637
# [270]	validation_0-auc:0.50610
# [271]	validation_0-auc:0.50616
# [272]	validation_0-auc:0.50613
# [273]	validation_0-auc:0.50681
# [274]	validation_0-auc:0.50623
# [275]	validation_0-auc:0.50681
# [276]	validation_0-auc:0.50648
# [277]	validation_0-auc:0.50599
# [278]	validation_0-auc:0.50588
# [279]	validation_0-auc:0.50610
# [280]	validation_0-auc:0.50556
# [281]	validation_0-auc:0.50542
# [282]	validation_0-auc:0.50511
# [283]	validation_0-auc:0.50540
# [284]	validation_0-auc:0.50478
# [285]	validation_0-auc:0.50452
# [286]	validation_0-auc:0.50460
# [287]	validation_0-auc:0.50489
# [288]	validation_0-auc:0.50487
# [289]	validation_0-auc:0.50498
# [290]	validation_0-auc:0.50482
# [291]	validation_0-auc:0.50571
# [292]	validation_0-auc:0.50606
# [293]	validation_0-auc:0.50616
# [294]	validation_0-auc:0.50615
# [295]	validation_0-auc:0.50654
# [296]	validation_0-auc:0.50672
# [297]	validation_0-auc:0.50722
# [298]	validation_0-auc:0.50762
# [299]	validation_0-auc:0.50775
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %% [markdown]
# # Evaluating on test

# %%
print("\nEvaluating XGBoost on test set...")
y_pred_proba = xgb.predict_proba(X_test)[:,1]
y_pred = (y_pred_proba >= 0.5).astype(int)
print("ROC AUC:", roc_auc_score(y_test, y_pred_proba))
print(classification_report(y_test, y_pred, digits=4))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Evaluating XGBoost on test set...
# ROC AUC: 0.5044504025726075
#               precision    recall  f1-score   support
#
#            0     0.8505    0.9997    0.9191     10029
#            1     0.0000    0.0000    0.0000      1762
#
#     accuracy                         0.8503     11791
#    macro avg     0.4253    0.4999    0.4595     11791
# weighted avg     0.7234    0.8503    0.7818     11791
#
# Confusion matrix:
#  [[10026     3]
#  [ 1762     0]]

# %% [markdown]
# # Quick inference example for a new HADM_ID (reuse parts of pipeline)

# %%
def predict_hadm(hadm_id, ad_df=ad, diag_vectorizer=diag_vec, proc_vectorizer=proc_vec, encoder=ohe, xgb_model=xgb):
    """Return probability of denial for a given HADM_ID (if in current ad_df)."""
    row = ad_df[ad_df['HADM_ID']==hadm_id]
    if row.empty:
        raise ValueError("HADM_ID not found.")
        
    # cat
    cat_arr = row[cat_cols].fillna('MISSING')
    cat_sp = encoder.transform(cat_arr)
    # diag/proc
    diag_sp = diag_vectorizer.transform(row['DIAG_CODES'])
    proc_sp = proc_vectorizer.transform(row['PROC_CODES'])
    X_new = hstack([cat_sp, diag_sp, proc_sp], format='csr')
    prob = xgb_model.predict_proba(X_new)[:,1][0]
    return prob

# %% [markdown]
# # Example usage (pick a random HADM_ID from test set)

# %%
example_hadm = num_df.index[0]
print(f"\nExample prediction for HADM_ID {example_hadm}: denial probability = {predict_hadm(example_hadm):.4f}")

print("\nPipeline complete. Replace synthetic labels with real claim denial labels before final evaluation.")
# Out:
# Example prediction for HADM_ID 165315: denial probability = 0.1878
#
# Pipeline complete. Replace synthetic labels with real claim denial labels before final evaluation.

# %% [markdown]
# # WE JUST HAVE TO REPLACE SYNTHETIC LABELS WITH REAL CLAIM DENIAL LABELS IN ABOVE CODE
